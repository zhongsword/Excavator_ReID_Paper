# %%
# from torchsummary import summary
from model.lstm import Pipline4Action
# import torch
def model_structure(model):
    blank = ' '
    print('-' * 90)
    print('|' + ' ' * 11 + 'weight name' + ' ' * 10 + '|'
          + ' ' * 15 + 'weight shape' + ' ' * 15 + '|'
          + ' ' * 3 + 'number' + ' ' * 3 + '|')
    print('-' * 90)
    num_para = 0
    type_size = 1  # 如果是浮点数就是4

    for index, (key, w_variable) in enumerate(model.named_parameters()):
        if len(key) <= 30:
            key = key + (30 - len(key)) * blank
        shape = str(w_variable.shape)
        if len(shape) <= 40:
            shape = shape + (40 - len(shape)) * blank
        each_para = 1
        for k in w_variable.shape:
            each_para *= k
        num_para += each_para
        str_num = str(each_para)
        if len(str_num) <= 10:
            str_num = str_num + (10 - len(str_num)) * blank

        print('| {} | {} | {} |'.format(key, shape, str_num))
    print('-' * 90)
    print('The total number of parameters: ' + str(num_para))
    print('The parameters of Model {}: {:4f}M'.format(
        model._get_name(), num_para * type_size / 1000 / 1000))
    print('-' * 90)

model = Pipline4Action(num_classes=3, frame_seq_length=32)

model_structure(model)
# Out:
# pooling_type: avg
# /home/zlj/Excavator_ReID/venv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zlj/Excavator_ReID/venv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ------------------------------------------------------------------------------------------
# |           weight name          |               weight shape               |   number   |
# ------------------------------------------------------------------------------------------
# | cnn.base.0.weight              | torch.Size([64, 3, 7, 7])                | 9408       |
# | cnn.base.1.weight              | torch.Size([64])                         | 64         |
# | cnn.base.1.bias                | torch.Size([64])                         | 64         |
# | cnn.base.4.0.conv1.weight      | torch.Size([64, 64, 3, 3])               | 36864      |
# | cnn.base.4.0.bn1.weight        | torch.Size([64])                         | 64         |
# | cnn.base.4.0.bn1.bias          | torch.Size([64])                         | 64         |
# | cnn.base.4.0.conv2.weight      | torch.Size([64, 64, 3, 3])               | 36864      |
# | cnn.base.4.0.bn2.weight        | torch.Size([64])                         | 64         |
# | cnn.base.4.0.bn2.bias          | torch.Size([64])                         | 64         |
# | cnn.base.4.1.conv1.weight      | torch.Size([64, 64, 3, 3])               | 36864      |
# | cnn.base.4.1.bn1.weight        | torch.Size([64])                         | 64         |
# | cnn.base.4.1.bn1.bias          | torch.Size([64])                         | 64         |
# | cnn.base.4.1.conv2.weight      | torch.Size([64, 64, 3, 3])               | 36864      |
# | cnn.base.4.1.bn2.weight        | torch.Size([64])                         | 64         |
# | cnn.base.4.1.bn2.bias          | torch.Size([64])                         | 64         |
# | cnn.base.4.2.conv1.weight      | torch.Size([64, 64, 3, 3])               | 36864      |
# | cnn.base.4.2.bn1.weight        | torch.Size([64])                         | 64         |
# | cnn.base.4.2.bn1.bias          | torch.Size([64])                         | 64         |
# | cnn.base.4.2.conv2.weight      | torch.Size([64, 64, 3, 3])               | 36864      |
# | cnn.base.4.2.bn2.weight        | torch.Size([64])                         | 64         |
# | cnn.base.4.2.bn2.bias          | torch.Size([64])                         | 64         |
# | cnn.base.5.0.conv1.weight      | torch.Size([128, 64, 3, 3])              | 73728      |
# | cnn.base.5.0.bn1.weight        | torch.Size([128])                        | 128        |
# | cnn.base.5.0.bn1.bias          | torch.Size([128])                        | 128        |
# | cnn.base.5.0.conv2.weight      | torch.Size([128, 128, 3, 3])             | 147456     |
# | cnn.base.5.0.bn2.weight        | torch.Size([128])                        | 128        |
# | cnn.base.5.0.bn2.bias          | torch.Size([128])                        | 128        |
# | cnn.base.5.0.downsample.0.weight | torch.Size([128, 64, 1, 1])              | 8192       |
# | cnn.base.5.0.downsample.1.weight | torch.Size([128])                        | 128        |
# | cnn.base.5.0.downsample.1.bias | torch.Size([128])                        | 128        |
# | cnn.base.5.1.conv1.weight      | torch.Size([128, 128, 3, 3])             | 147456     |
# | cnn.base.5.1.bn1.weight        | torch.Size([128])                        | 128        |
# | cnn.base.5.1.bn1.bias          | torch.Size([128])                        | 128        |
# | cnn.base.5.1.conv2.weight      | torch.Size([128, 128, 3, 3])             | 147456     |
# | cnn.base.5.1.bn2.weight        | torch.Size([128])                        | 128        |
# | cnn.base.5.1.bn2.bias          | torch.Size([128])                        | 128        |
# | cnn.base.5.2.conv1.weight      | torch.Size([128, 128, 3, 3])             | 147456     |
# | cnn.base.5.2.bn1.weight        | torch.Size([128])                        | 128        |
# | cnn.base.5.2.bn1.bias          | torch.Size([128])                        | 128        |
# | cnn.base.5.2.conv2.weight      | torch.Size([128, 128, 3, 3])             | 147456     |
# | cnn.base.5.2.bn2.weight        | torch.Size([128])                        | 128        |
# | cnn.base.5.2.bn2.bias          | torch.Size([128])                        | 128        |
# | cnn.base.5.3.conv1.weight      | torch.Size([128, 128, 3, 3])             | 147456     |
# | cnn.base.5.3.bn1.weight        | torch.Size([128])                        | 128        |
# | cnn.base.5.3.bn1.bias          | torch.Size([128])                        | 128        |
# | cnn.base.5.3.conv2.weight      | torch.Size([128, 128, 3, 3])             | 147456     |
# | cnn.base.5.3.bn2.weight        | torch.Size([128])                        | 128        |
# | cnn.base.5.3.bn2.bias          | torch.Size([128])                        | 128        |
# | cnn.base.6.0.conv1.weight      | torch.Size([256, 128, 3, 3])             | 294912     |
# | cnn.base.6.0.bn1.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.0.bn1.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.0.conv2.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.0.bn2.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.0.bn2.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.0.downsample.0.weight | torch.Size([256, 128, 1, 1])             | 32768      |
# | cnn.base.6.0.downsample.1.weight | torch.Size([256])                        | 256        |
# | cnn.base.6.0.downsample.1.bias | torch.Size([256])                        | 256        |
# | cnn.base.6.1.conv1.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.1.bn1.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.1.bn1.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.1.conv2.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.1.bn2.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.1.bn2.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.2.conv1.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.2.bn1.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.2.bn1.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.2.conv2.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.2.bn2.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.2.bn2.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.3.conv1.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.3.bn1.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.3.bn1.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.3.conv2.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.3.bn2.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.3.bn2.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.4.conv1.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.4.bn1.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.4.bn1.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.4.conv2.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.4.bn2.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.4.bn2.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.5.conv1.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.5.bn1.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.5.bn1.bias          | torch.Size([256])                        | 256        |
# | cnn.base.6.5.conv2.weight      | torch.Size([256, 256, 3, 3])             | 589824     |
# | cnn.base.6.5.bn2.weight        | torch.Size([256])                        | 256        |
# | cnn.base.6.5.bn2.bias          | torch.Size([256])                        | 256        |
# | cnn.base.7.0.conv1.weight      | torch.Size([512, 256, 3, 3])             | 1179648    |
# | cnn.base.7.0.bn1.weight        | torch.Size([512])                        | 512        |
# | cnn.base.7.0.bn1.bias          | torch.Size([512])                        | 512        |
# | cnn.base.7.0.conv2.weight      | torch.Size([512, 512, 3, 3])             | 2359296    |
# | cnn.base.7.0.bn2.weight        | torch.Size([512])                        | 512        |
# | cnn.base.7.0.bn2.bias          | torch.Size([512])                        | 512        |
# | cnn.base.7.0.downsample.0.weight | torch.Size([512, 256, 1, 1])             | 131072     |
# | cnn.base.7.0.downsample.1.weight | torch.Size([512])                        | 512        |
# | cnn.base.7.0.downsample.1.bias | torch.Size([512])                        | 512        |
# | cnn.base.7.1.conv1.weight      | torch.Size([512, 512, 3, 3])             | 2359296    |
# | cnn.base.7.1.bn1.weight        | torch.Size([512])                        | 512        |
# | cnn.base.7.1.bn1.bias          | torch.Size([512])                        | 512        |
# | cnn.base.7.1.conv2.weight      | torch.Size([512, 512, 3, 3])             | 2359296    |
# | cnn.base.7.1.bn2.weight        | torch.Size([512])                        | 512        |
# | cnn.base.7.1.bn2.bias          | torch.Size([512])                        | 512        |
# | cnn.base.7.2.conv1.weight      | torch.Size([512, 512, 3, 3])             | 2359296    |
# | cnn.base.7.2.bn1.weight        | torch.Size([512])                        | 512        |
# | cnn.base.7.2.bn1.bias          | torch.Size([512])                        | 512        |
# | cnn.base.7.2.conv2.weight      | torch.Size([512, 512, 3, 3])             | 2359296    |
# | cnn.base.7.2.bn2.weight        | torch.Size([512])                        | 512        |
# | cnn.base.7.2.bn2.bias          | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l0              | torch.Size([512, 512])                   | 262144     |
# | lstm.weight_hh_l0              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l0                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l0                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l1              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l1              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l1                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l1                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l2              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l2              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l2                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l2                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l3              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l3              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l3                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l3                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l4              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l4              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l4                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l4                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l5              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l5              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l5                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l5                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l6              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l6              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l6                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l6                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l7              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l7              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l7                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l7                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l8              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l8              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l8                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l8                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l9              | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l9              | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l9                | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l9                | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l10             | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l10             | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l10               | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l10               | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l11             | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l11             | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l11               | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l11               | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l12             | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l12             | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l12               | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l12               | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l13             | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l13             | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l13               | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l13               | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l14             | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l14             | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l14               | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l14               | torch.Size([512])                        | 512        |
# | lstm.weight_ih_l15             | torch.Size([512, 128])                   | 65536      |
# | lstm.weight_hh_l15             | torch.Size([512, 128])                   | 65536      |
# | lstm.bias_ih_l15               | torch.Size([512])                        | 512        |
# | lstm.bias_hh_l15               | torch.Size([512])                        | 512        |
# | classifier.weight              | torch.Size([3, 128])                     | 384        |
# | classifier.bias                | torch.Size([3])                          | 3          |
# ------------------------------------------------------------------------------------------
# The total number of parameters: 23595203
# The parameters of Model Pipline4Action: 23.595203M
# ------------------------------------------------------------------------------------------
